# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from config import INPUT_EXPRESSION_DATA, INPUT_GROUP_DATA
from data_processing import data_loader
import GSM_pipeline
import pathlib
from utils import logger

project_folder = pathlib.Path().resolve().parent
print(f"Project Folder: {project_folder}")

# Now you can import the GSM_pipeline module
input_file = project_folder / INPUT_EXPRESSION_DATA
group_file = project_folder / INPUT_GROUP_DATA

input_data = data_loader.load_input_file(input_file)
group_data = data_loader.load_group_file(group_file)

GSM_pipeline.gsm_run(input_data, group_data)
# Out:
# Project Folder: /home/yasin/GSM-to-python
# /home/yasin/GSM-to-python/data/test/test_main_data.csv
# ✨ 2025-06-03 23:39:48,295 - gsm_pipeline - INFO - 🚀 Starting GSM pipeline...
# ✨ 2025-06-03 23:39:48,296 - gsm_pipeline - INFO - Start data preprocessing.
# ✨ 2025-06-03 23:39:48,302 - gsm_pipeline - INFO - Starting data normalization using zscore method
# ✨ 2025-06-03 23:39:48,318 - gsm_pipeline - INFO - Data normalization completed successfully
# ✨ 2025-06-03 23:39:48,325 - gsm_pipeline - INFO - Class counts: class
# 1    157
# 0     23
# Name: count, dtype: int64
# ✨ 2025-06-03 23:39:48,348 - gsm_pipeline - INFO - Balanced class counts: class
# 0    23
# 1    23
# Name: count, dtype: int64
# ✨ 2025-06-03 23:39:48,350 - gsm_pipeline - INFO - Class balance ratio 1.0 is acceptable
# ✨ 2025-06-03 23:39:48,351 - gsm_pipeline - INFO - Sampled data size: (46, 136)
# ✨ 2025-06-03 23:39:48,352 - gsm_pipeline - INFO - Data shape: (46, 136)
# ✨ 2025-06-03 23:39:48,353 - gsm_pipeline - INFO - Data columns: ['class', 'AFG3L1P', 'ACACB', 'ACP1', 'ADCY7', 'ACAT1', 'ACAN', 'A2M', 'AP2A1', 'ACVR2B', 'AKT2', 'ABR', 'ABCA4', 'ABCA1', 'ABCF1', 'ACTN4', 'AP2B1', 'ACADVL', 'ACO2', 'ACTB', 'AHCY', 'ACTA2', 'ADD3', 'ACLY', 'GRK2', 'AAMP', 'ACTG1', 'ADAR', 'AEBP1', 'ACAA1', 'ABL1', 'ADSL', 'PARP4', 'ACTG2', 'ACADS', 'SERPINA3', 'ACADM', 'AK1', 'ADAM10', 'ACTL6A', 'ACP2', 'AHR', 'AGT', 'ADM', 'AP1G1', 'AOC1', 'AGL', 'ACTN2', 'ADARB1', 'ACTA1', 'ACVR1', 'ADK', 'GRK3', 'AGA', 'ABCA3', 'ADCY9', 'AHSG', 'ACP5', 'ADA', 'AFP', 'ACTC1', 'ASIC1', 'ADAM8', 'ACVR1B', 'ADD2', 'ACVR2A', 'ACADSB', 'AGTR1', 'ACHE', 'AP1B1', 'ADORA1', 'ADORA2B', 'AADAC', 'AK2', 'ACADL', 'ADRA2C', 'ADRB2', 'ADORA3', 'ADH1C', 'ADCYAP1', 'ABL2', 'ABAT', 'NR0B1', 'ASIC2', 'NAT2', 'ADCY8', 'ADRB3', 'AFM', 'ACTN3', 'AGXT', 'CRISP1', 'ACO1', 'ADCYAP1R1', 'AKT1', 'AGRP', 'AANAT', 'AGTR2', 'ACR', 'ADH6', 'ADRA1B', 'ACOX1', 'ADH1A', 'AIF1', 'ADPRH', 'ADD1', 'ADRB1', 'ADRA2B', 'ACTN1', 'PARP1', 'ADH5', 'JAG1', 'PLIN2', 'ADCY6', 'ADCY3', 'ACAT2', 'ADH1B', 'ABCB7', 'ADRA2A', 'AGER', 'ABCA2', 'ADH7', 'ACVRL1', 'ADRA1D', 'ADRA1A', 'AP2A2', 'ACACA', 'ADCY2', 'ADCY1', 'APLNR', 'NAT1', 'ABO', 'ADARB2', 'ADH4', 'ADCY5', 'A1BG', 'ACY1']
# ✨ 2025-06-03 23:39:48,364 - gsm_pipeline - INFO - Data head:
#    class   AFG3L1P     ACACB      ACP1     ADCY7     ACAT1      ACAN  \
# 0      0 -0.967032  0.436792 -0.907665 -0.076029 -0.548163  2.074762
# 1      0 -0.536779  0.302999 -0.640462  0.626819  0.512016  1.090512
# 2      0 -0.970062  1.203651 -0.797640  9.014519  1.823203  0.270304
# 3      0 -0.626379  1.964347 -0.995235 -0.244480  0.667245  1.981024
# 4      0 -0.180975 -1.225281 -0.622499  1.294814 -0.165045 -0.818229
#
#         A2M     AP2A1    ACVR2B  ...     ADCY2     ADCY1     APLNR      NAT1  \
# 0  0.426023  0.159444 -0.666904  ...  0.260929  2.306027 -0.263003 -0.675729
# 1  0.671704 -0.857448 -0.543987  ... -0.040291  1.353877 -0.115452 -0.549406
# 2  0.660434  0.362596 -0.372153  ...  0.460487  1.606642 -0.583283 -0.783883
# 3  1.627380 -0.919869 -0.309440  ... -0.133961  1.183768 -0.484460 -0.486244
# 4 -0.419211 -0.975480 -0.493816  ...  0.023977  1.954998 -0.362195 -1.142087
#
#         ABO    ADARB2      ADH4     ADCY5      A1BG      ACY1
# 0  0.751329  0.535498  1.336963  0.205543  0.263486 -0.252070
# 1  0.298903  0.308118 -0.208955  1.175643 -0.481563 -0.137433
# 2  0.461776  0.605948  0.483762  1.115228  1.196490  0.641149
# 3  0.126981  0.002273  0.204102 -0.871919  2.082082  4.046844
# 4 -0.587852  0.304322 -0.493355  2.673315  1.987257 -0.686738
#
# [5 rows x 136 columns]
# ✨ 2025-06-03 23:39:48,365 - gsm_pipeline - INFO - Data preprocessing completed.
# ✨ 2025-06-03 23:39:48,366 - gsm_pipeline - INFO - Grouping data shape: (36, 2)
# ✨ 2025-06-03 23:39:48,367 - gsm_pipeline - INFO - Grouping data columns: ['geneSymbol', 'diseaseName']
# ✨ 2025-06-03 23:39:48,368 - gsm_pipeline - INFO - Grouping data head:
#   geneSymbol                          diseaseName
# 0       A1BG                         Glioblastoma
# 1       A1BG                           Meningioma
# 2       A1BG  Subependymal Giant Cell Astrocytoma
# 3       A1BG               Hepatocellular Adenoma
# 4        A2M                          Astrocytoma
# ✨ 2025-06-03 23:39:48,369 - gsm_pipeline - INFO - Grouping data preprocessing completed.
# ✨ 2025-06-03 23:39:48,371 - gsm_pipeline - INFO - ==================================================
# ✨ 2025-06-03 23:39:48,371 - gsm_pipeline - INFO - Iteration 1 for gsm_main_loop started...
# ✨ 2025-06-03 23:39:48,372 - gsm_pipeline - INFO - Random seed set to: 1042
# ✨ 2025-06-03 23:39:48,373 - gsm_pipeline - INFO - ##### Starting GSM Main Loop #####
# ✨ 2025-06-03 23:39:48,374 - gsm_pipeline - INFO - 📊 Splitting data into training and testing sets...
# ✨ 2025-06-03 23:39:48,388 - gsm_pipeline - INFO - Data split completed.
# ✨ 2025-06-03 23:39:48,389 - gsm_pipeline - INFO - 🔍 Applying preliminary t-test filter...
# ✨ 2025-06-03 23:39:48,389 - gsm_pipeline - INFO - Starting preliminary filtering...
# ✨ 2025-06-03 23:39:48,391 - gsm_pipeline - INFO - ##### Running t-test on 135 genes #####
# ✨ 2025-06-03 23:39:48,396 - gsm_pipeline - INFO - Applying fdr_bh correction
# ✨ 2025-06-03 23:39:48,397 - gsm_pipeline - INFO - ✅ Selected 37 significant genes
# ✨ 2025-06-03 23:39:48,398 - gsm_pipeline - INFO - ✅ Final selection: 37 genes after size filter (INITIAL_FEATURE_FILTER_SIZE=1000)
# ✨ 2025-06-03 23:39:48,399 - gsm_pipeline - INFO - Preliminary filtering completed. Selected 37 features.
# ✨ 2025-06-03 23:39:48,400 - gsm_pipeline - INFO - Preliminary filtering completed.
# ✨ 2025-06-03 23:39:48,401 - gsm_pipeline - INFO - 🔗 Running gene grouping analysis...
# ✨ 2025-06-03 23:39:48,402 - gsm_pipeline - INFO - ##################################################
# ✨ 2025-06-03 23:39:48,402 - gsm_pipeline - INFO - 🔄 Starting grouping process...
# ✨ 2025-06-03 23:39:48,403 - gsm_pipeline - INFO - 🔄 Creating group-feature mappings...
# ✨ 2025-06-03 23:39:48,405 - gsm_pipeline - INFO - ✅ Created 26 group-feature mappings
# ✨ 2025-06-03 23:39:48,407 - gsm_pipeline - INFO - 📊 Top 5 largest groups:
# ✨ 2025-06-03 23:39:48,408 - gsm_pipeline - INFO -   1. Malignant tumor of colon: 3 features
# ✨ 2025-06-03 23:39:48,409 - gsm_pipeline - INFO -   2. Hepatocellular Adenoma: 2 features
# ✨ 2025-06-03 23:39:48,409 - gsm_pipeline - INFO -   3. Astrocytoma: 2 features
# ✨ 2025-06-03 23:39:48,411 - gsm_pipeline - INFO -   4. Malignant neoplasm of urinary bladder: 2 features
# ✨ 2025-06-03 23:39:48,412 - gsm_pipeline - INFO -   5. Bladder Neoplasm: 2 features
# ✨ 2025-06-03 23:39:48,413 - gsm_pipeline - INFO - 📊 Total features in groups: 36
# ✨ 2025-06-03 23:39:48,414 - gsm_pipeline - INFO - 📊 Average group size: 1.38 features
# ✨ 2025-06-03 23:39:48,415 - gsm_pipeline - INFO - ✅ Grouping data validation successful
# ✨ 2025-06-03 23:39:48,417 - gsm_pipeline - INFO - ✅ Successfully processed 26 feature groups
# ✨ 2025-06-03 23:39:48,418 - gsm_pipeline - INFO - Grouping completed.
# ✨ 2025-06-03 23:39:48,419 - gsm_pipeline - INFO - 📈 Evaluating group performance...
# ✨ 2025-06-03 23:39:48,420 - gsm_pipeline - INFO - 🎯 Starting feature scoring...
# ✨ 2025-06-03 23:39:48,420 - gsm_pipeline - INFO - 📊 Scoring 135 features...
# ✨ 2025-06-03 23:39:49,007 - gsm_pipeline - INFO - ✅ Feature scoring completed
# ✨ 2025-06-03 23:39:49,008 - gsm_pipeline - INFO - ✅ Completed scoring 135 features
# ✨ 2025-06-03 23:39:49,008 - gsm_pipeline - INFO - ##################################################
# ✨ 2025-06-03 23:39:49,009 - gsm_pipeline - INFO - 🔍 Found the following groups:['Glioblastoma', 'Meningioma', 'Subependymal Giant Cell Astrocytoma', 'Hepatocellular Adenoma', 'Astrocytoma', 'Malignant tumor of colon', 'liposarcoma', 'melanoma', 'Myelomonocytic leukemia', 'Secondary malignant neoplasm of bone', 'Hepatoblastoma', 'Colon Carcinoma', 'Liver carcinoma', 'Hepatoblastoma Caused By Somatic Mutation', 'Childhood Astrocytoma', 'Malignant neoplasm of urinary bladder', 'Bladder Neoplasm', 'Malignant neoplasm of breast', 'Malignant neoplasm of larynx', 'Rectal Carcinoma', 'Non-Small Cell Lung Carcinoma', 'Female Breast Carcinoma', 'Malignant neoplasm of thyroid', 'Bronchogenic Carcinoma', 'Renal Cell Carcinoma', 'Squamous cell carcinoma']
# ✨ 2025-06-03 23:39:49,011 - gsm_pipeline - INFO - 🔍 Found 135 features in the dataset
# ✨ 2025-06-03 23:39:49,012 - gsm_pipeline - INFO - 🔍 Found 26 groups in the dataset
# ✨ 2025-06-03 23:39:49,012 - gsm_pipeline - INFO - 🔍 Found 36 samples in the dataset
# ✨ 2025-06-03 23:39:49,013 - gsm_pipeline - INFO - 🔍 Found 135 features in the dataset
# ✨ 2025-06-03 23:39:49,014 - gsm_pipeline - INFO - 🔍 Found 2 unique labels in the dataset
# ✨ 2025-06-03 23:39:49,015 - gsm_pipeline - INFO - 🔍 Found 26 groups in the dataset
# ✨ 2025-06-03 23:39:49,015 - gsm_pipeline - INFO - 🔄 Starting group scoring process...
# 📊 Scoring groups:  50%|█████     | 13/26 [00:08<00:08,  1.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1749/1378792206.py in ?()
#      17
#      18 input_data = data_loader.load_input_file(input_file)
#      19 group_data = data_loader.load_group_file(group_file)
#      20
# ---> 21 GSM_pipeline.gsm_run(input_data, group_data)
#
# ~/GSM-to-python/src/GSM_pipeline.py in ?(input_data, group_data, sample_ratio, n_iterations, model_name, label_column, normalization_method, initial_seed, logger_path, notebook_mode)
#     135         # Set random seed for reproducibility
#     136         iteration_seed = generate_iteration_seed(initial_seed, i)
#     137         set_random_seed(iteration_seed, logger)
#     138
# --> 139         modeling_result = gsm_main_loop(
#     140             data=data_preprocessed,
#     141             grouping_data=group_data_processed,
#     142             model_name=model_name,
#
# ~/GSM-to-python/src/GSM_pipeline.py in ?(data, grouping_data, model_name, output_dir, iteration, logger)
#     225     logger.info("Grouping completed.")
#     226
#     227     # Group Scoring
#     228     logger.info("📈 Evaluating group performance...")
# --> 229     scoring_results = run_scoring(data_x=train_test_split_data.X_train,
#     230                                 labels=train_test_split_data.y_train,
#     231                                 model_name=model_name,
#     232                                 groups=group_feature_mappings,
#
# ~/GSM-to-python/src/scoring/run_scoring.py in ?(data_x, labels, model_name, groups, output_dir, iteration, logger)
#     146             feature_scores=feature_scores,
#     147             group_feature_mapping=group_features
#     148         )
#     149
# --> 150     except Exception as e:
#     151         logger.error(f"❌ Scoring pipeline failed: {str(e)}")
#     152         raise
#
# ~/GSM-to-python/src/scoring/score_data.py in ?(params)
#     107         # logger.info(f"📈 Accuracy: {metrics.accuracy:.3f} ± {metrics.accuracy_std:.3f}")
#     108
#     109         return metrics
#     110
# --> 111     except Exception as e:
#     112         if params.logger:
#     113             params.logger.error(f"❌ Error during scoring process: {str(e)}")
#     114         raise RuntimeError(f"Scoring process failed: {str(e)}")
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py in ?(*args, **kwargs)
#     213                         prefer_skip_nested_validation or global_skip_validation
#     214                     )
#     215                 ):
#     216                     return func(*args, **kwargs)
# --> 217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#     219                 # the function to delegate validation to the estimator, but we replace
#     220                 # the name of the estimator by the name of the function in the error
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py in ?(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     407
#     408     # We clone the estimator to make sure that all the folds are
#     409     # independent, and that it is pickle-able.
#     410     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 411     results = parallel(
#     412         delayed(_fit_and_score)(
#     413             clone(estimator),
#     414             X,
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/joblib/parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/joblib/parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py in ?(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     884     else:
#     885         result["fit_error"] = None
#     886
#     887         fit_time = time.time() - start_time
# --> 888         test_scores = _score(
#     889             estimator, X_test, y_test, scorer, score_params_test, error_score
#     890         )
#     891         score_time = time.time() - start_time - fit_time
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py in ?(estimator, X_test, y_test, scorer, score_params, error_score)
#     946         if y_test is None:
#     947             scores = scorer(estimator, X_test, **score_params)
#     948         else:
#     949             scores = scorer(estimator, X_test, y_test, **score_params)
# --> 950     except Exception:
#     951         if isinstance(scorer, _MultimetricScorer):
#     952             # If `_MultimetricScorer` raises exception, the `error_score`
#     953             # parameter is equal to "raise".
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py in ?(self, estimator, *args, **kwargs)
#     142                     )
#     143                 else:
#     144                     score = scorer(estimator, *args, **routed_params.get(name).score)
#     145                 scores[name] = score
# --> 146             except Exception as e:
#     147                 if self._raise_exc:
#     148                     raise e
#     149                 else:
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py in ?(self, method_caller, estimator, X, y_true, **kwargs)
#     376         )
#     377
#     378         pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     379         response_method = _check_response_method(estimator, self._response_method)
# --> 380         y_pred = method_caller(
#     381             estimator,
#     382             _get_response_method_name(response_method),
#     383             X,
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py in ?(cache, estimator, response_method, *args, **kwargs)
#      86     """Call estimator with method and args and kwargs."""
#      87     if cache is not None and response_method in cache:
#      88         return cache[response_method]
#      89
# ---> 90     result, _ = _get_response_values(
#      91         estimator, *args, response_method=response_method, **kwargs
#      92     )
#      93
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/_response.py in ?(estimator, X, response_method, pos_label, return_response_method_used)
#     210                 )
#     211             elif pos_label is None and target_type == "binary":
#     212                 pos_label = classes[-1]
#     213
# --> 214         y_pred = prediction_method(X)
#     215
#     216         if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     217             y_pred = _process_predict_proba(
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py in ?(self, X)
#     942             classes corresponds to that in the attribute :term:`classes_`.
#     943         """
#     944         check_is_fitted(self)
#     945         # Check data
# --> 946         X = self._validate_X_predict(X)
#     947
#     948         # Assign chunk of trees to jobs
#     949         n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py in ?(self, X)
#     634             ensure_all_finite = "allow-nan"
#     635         else:
#     636             ensure_all_finite = True
#     637
# --> 638         X = validate_data(
#     639             self,
#     640             X,
#     641             dtype=DTYPE,
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~/GSM-to-python/venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
# -> 6284     @final
#    6285     def __getattr__(self, name: str):
#    6286         """
#    6287         After regular attribute access, try looking up the name
#
# KeyboardInterrupt:
